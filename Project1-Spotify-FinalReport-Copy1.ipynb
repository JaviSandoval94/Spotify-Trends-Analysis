# %% [markdown]
# # Project-1-Spotify
#
# We are a consulting company for independent artists. We are helping a new Mexican artist to launch their next hit in Mexico and Latin America, which is planned to be released in last quarter 2020 in the Spotify platform, to remain in the Top 50 Chart throughout the next year.
#
# Tasks:
#
# * Identify most popular music genres in the population segment that the artist is targeting.
# * Identify patterns in the tempo, energy, danceability and acousticness of the music that people in that segment listen to in different quarters.
# * Define the properties that the artist's song should have to be succesful in last quarter 2020 in Mexico and Latin America.
# * Predict how popular this song will be in upcoming quarters.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

top50_chart_df = pd.read_excel("chartmx_03_20.xlsx", index = False)
stats_df = pd.read_excel("audiofmx.xlsx", index = False)

top50_chart_df["id"] = top50_chart_df["URL"].str[-22:]

top50_chart_df = top50_chart_df[["Position", "Track Name", "Artist", "Date", "id"]]

top50_chart_df.head()
# Out:
#    Position                                         Track Name  \
# 0         1  I'm Still Standing - From "Sing" Original Moti...
# 1         2                                       El Año Viejo
# 2         3                              La Edad de los Países
# 3         4  Shake It Off - From "Sing" Original Motion Pic...
# 4         5                                 Another Day Of Sun
#
#             Artist        Date                      id
# 0    Taron Egerton  2017-01-01  0mb7btREdC3wuIUmuVRgWn
# 1     Tony Camargo  2017-01-01  6NjhADkaWwGYO0R7eZXyI4
# 2  Hernán Casciari  2017-01-01  5gA5Tvu7zlihzqUvmPUqoi
# 3       Nick Kroll  2017-01-01  2Q0WZoJaRJlelcxqOvowUc
# 4  La La Land Cast  2017-01-01  5kRBzRZmZTXVg8okC7SJFZ

# %%
stats_df = stats_df[["acousticness", "danceability", "duration_ms", "energy", "id", "instrumentalness", "key", "liveness", "loudness", "mode", "speechiness", "tempo", "time_signature", "type", "valence"]]
stats_df.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0       0.00703         0.591       187853   0.901  0mb7btREdC3wuIUmuVRgWn
# 1       0.60200         0.740       182720   0.521  6NjhADkaWwGYO0R7eZXyI4
# 2       0.92300         0.606       280521   0.301  5gA5Tvu7zlihzqUvmPUqoi
# 3       0.11600         0.741       120560   0.913  2Q0WZoJaRJlelcxqOvowUc
# 4       0.01620         0.588       228173   0.742  5kRBzRZmZTXVg8okC7SJFZ
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000   10    0.0649    -4.328     0       0.1500  175.345
# 1          0.000000    0    0.1110   -10.663     1       0.3650  159.694
# 2          0.000000    9    0.2970   -15.735     0       0.8610   62.876
# 3          0.000001   11    0.0783    -5.453     1       0.2780  160.070
# 4          0.000004    8    0.6530    -6.757     1       0.0528  125.819
#
#    time_signature            type  valence
# 0               4  audio_features    0.694
# 1               4  audio_features    0.904
# 2               3  audio_features    0.941
# 3               4  audio_features    0.854
# 4               4  audio_features    0.824

# %%
complete_df = top50_chart_df.merge(stats_df, on = "id")
complete_df = complete_df[["Position", "Track Name", "Artist", "Date", "acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness", "loudness", "mode", "speechiness", "tempo", "time_signature", "type", "valence"]]
complete_df.head()
# Out:
#    Position                                         Track Name         Artist  \
# 0         1  I'm Still Standing - From "Sing" Original Moti...  Taron Egerton
# 1         1  I'm Still Standing - From "Sing" Original Moti...  Taron Egerton
# 2         1  I'm Still Standing - From "Sing" Original Moti...  Taron Egerton
# 3         1  I'm Still Standing - From "Sing" Original Moti...  Taron Egerton
# 4         1  I'm Still Standing - From "Sing" Original Moti...  Taron Egerton
#
#          Date  acousticness  danceability  duration_ms  energy  \
# 0  2017-01-01       0.00703         0.591       187853   0.901
# 1  2017-01-02       0.00703         0.591       187853   0.901
# 2  2017-01-03       0.00703         0.591       187853   0.901
# 3  2017-01-04       0.00703         0.591       187853   0.901
# 4  2017-01-05       0.00703         0.591       187853   0.901
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0   10    0.0649    -4.328     0         0.15  175.345
# 1               0.0   10    0.0649    -4.328     0         0.15  175.345
# 2               0.0   10    0.0649    -4.328     0         0.15  175.345
# 3               0.0   10    0.0649    -4.328     0         0.15  175.345
# 4               0.0   10    0.0649    -4.328     0         0.15  175.345
#
#    time_signature            type  valence
# 0               4  audio_features    0.694
# 1               4  audio_features    0.694
# 2               4  audio_features    0.694
# 3               4  audio_features    0.694
# 4               4  audio_features    0.694

# %%
complete_df=complete_df.dropna()
complete_df
# Out:
#        Position                                         Track Name  \
# 0             1  I'm Still Standing - From "Sing" Original Moti...
# 1             1  I'm Still Standing - From "Sing" Original Moti...
# 2             1  I'm Still Standing - From "Sing" Original Moti...
# 3             1  I'm Still Standing - From "Sing" Original Moti...
# 4             1  I'm Still Standing - From "Sing" Original Moti...
# ...         ...                                                ...
# 44850        45                             De Los Besos Que Te Di
# 44851        45                             De Los Besos Que Te Di
# 44852        44                                          Presiento
# 44853        44                                          Presiento
# 44854        45                                          Presiento
#
#                 Artist        Date  acousticness  danceability  duration_ms  \
# 0        Taron Egerton  2017-01-01       0.00703         0.591       187853
# 1        Taron Egerton  2017-01-02       0.00703         0.591       187853
# 2        Taron Egerton  2017-01-03       0.00703         0.591       187853
# 3        Taron Egerton  2017-01-04       0.00703         0.591       187853
# 4        Taron Egerton  2017-01-05       0.00703         0.591       187853
# ...                ...         ...           ...           ...          ...
# 44850  Christian Nodal  2019-06-01       0.38800         0.504       167373
# 44851  Christian Nodal  2019-06-02       0.38800         0.504       167373
# 44852            Morat  2019-05-10       0.16800         0.711       174380
# 44853            Morat  2019-05-11       0.16800         0.711       174380
# 44854            Morat  2019-05-12       0.16800         0.711       174380
#
#        energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0       0.901               0.0   10    0.0649    -4.328     0       0.1500
# 1       0.901               0.0   10    0.0649    -4.328     0       0.1500
# 2       0.901               0.0   10    0.0649    -4.328     0       0.1500
# 3       0.901               0.0   10    0.0649    -4.328     0       0.1500
# 4       0.901               0.0   10    0.0649    -4.328     0       0.1500
# ...       ...               ...  ...       ...       ...   ...          ...
# 44850   0.503               0.0    7    0.0608    -3.313     1       0.0422
# 44851   0.503               0.0    7    0.0608    -3.313     1       0.0422
# 44852   0.727               0.0    2    0.2960    -3.150     1       0.1620
# 44853   0.727               0.0    2    0.2960    -3.150     1       0.1620
# 44854   0.727               0.0    2    0.2960    -3.150     1       0.1620
#
#          tempo  time_signature            type  valence
# 0      175.345               4  audio_features    0.694
# 1      175.345               4  audio_features    0.694
# 2      175.345               4  audio_features    0.694
# 3      175.345               4  audio_features    0.694
# 4      175.345               4  audio_features    0.694
# ...        ...             ...             ...      ...
# 44850  195.593               4  audio_features    0.709
# 44851  195.593               4  audio_features    0.709
# 44852  180.039               4  audio_features    0.465
# 44853  180.039               4  audio_features    0.465
# 44854  180.039               4  audio_features    0.465
#
# [44846 rows x 18 columns]

# %% [markdown]
# ## Hypothesis: If we determine the optimal mix of the variables related to a successful song in Mexico, then we can help the artist release a successful song in the last quarter of 2020:

# %% [markdown]
# ## If the tempo of a song is higher than 100 bpm, then it will be more popular.

# %% [markdown]
# ## If the chooses to release a reggaeton song, then it will remain in the Top 50 Chart throughout the next year.

# %% [markdown]
# ## If a song has a higher level of energy, then it will be more likely to be in the Top 50 throughout the next year.

# %%
#Track name

# %%
track_name=complete_df.groupby(["Track Name"])
track_name.count().head()
# Out:
#                                                     Position  Artist  Date  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...         6       6     6
# #Maldeamores                                              10      10    10
# #Natural                                                  31      31    31
# (I Just) Died In Your Arms                                 1       1     1
# (No One Knows Me) Like the Piano                           5       5     5
#
#                                                     acousticness  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...             6
# #Maldeamores                                                  10
# #Natural                                                      31
# (I Just) Died In Your Arms                                     1
# (No One Knows Me) Like the Piano                               5
#
#                                                     danceability  duration_ms  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...             6            6
# #Maldeamores                                                  10           10
# #Natural                                                      31           31
# (I Just) Died In Your Arms                                     1            1
# (No One Knows Me) Like the Piano                               5            5
#
#                                                     energy  instrumentalness  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...       6                 6
# #Maldeamores                                            10                10
# #Natural                                                31                31
# (I Just) Died In Your Arms                               1                 1
# (No One Knows Me) Like the Piano                         5                 5
#
#                                                     key  liveness  loudness  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...    6         6         6
# #Maldeamores                                         10        10        10
# #Natural                                             31        31        31
# (I Just) Died In Your Arms                            1         1         1
# (No One Knows Me) Like the Piano                      5         5         5
#
#                                                     mode  speechiness  tempo  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...     6            6      6
# #Maldeamores                                          10           10     10
# #Natural                                              31           31     31
# (I Just) Died In Your Arms                             1            1      1
# (No One Knows Me) Like the Piano                       5            5      5
#
#                                                     time_signature  type  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...               6     6
# #Maldeamores                                                    10    10
# #Natural                                                        31    31
# (I Just) Died In Your Arms                                       1     1
# (No One Knows Me) Like the Piano                                 5     5
#
#                                                     valence
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...        6
# #Maldeamores                                             10
# #Natural                                                 31
# (I Just) Died In Your Arms                                1
# (No One Knows Me) Like the Piano                          5

# %%
track_name_count=pd.DataFrame(track_name["Position"].count())
track_name_count.rename(columns={"Position":"Number of times in the chart TOP 50"},inplace=True)
track_name_count.head()
# Out:
#                                                     Number of times in the chart TOP 50
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...                                    6
# #Maldeamores                                                                         10
# #Natural                                                                             31
# (I Just) Died In Your Arms                                                            1
# (No One Knows Me) Like the Piano                                                      5

# %%
energy_data=pd.DataFrame(track_name["energy"].mean())
energy_data.rename(columns={"energy":"Energy"},inplace=True)
energy_data.head()
# Out:
#                                                       Energy
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...  0.719000
# #Maldeamores                                        0.804000
# #Natural                                            0.824677
# (I Just) Died In Your Arms                          0.726000
# (No One Knows Me) Like the Piano                    0.198000

# %%
merge5_df=pd.merge(track_name_count, energy_data, on="Track Name", how="outer")
merge5_df
# Out:
#                                                     Number of times in the chart TOP 50  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...                                    6
# #Maldeamores                                                                         10
# #Natural                                                                             31
# (I Just) Died In Your Arms                                                            1
# (No One Knows Me) Like the Piano                                                      5
# ...                                                                                 ...
# 달라달라 (DALLA DALLA)                                                                   10
# 봄날의 소나기 Paper Umbrella                                                                3
# 전야 前夜 The Eve                                                                         1
# 피카부 Peek-A-Boo                                                                        6
# 항상 (HANGSANG)                                                                         7
#
#                                                       Energy
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...  0.719000
# #Maldeamores                                        0.804000
# #Natural                                            0.824677
# (I Just) Died In Your Arms                          0.726000
# (No One Knows Me) Like the Piano                    0.198000
# ...                                                      ...
# 달라달라 (DALLA DALLA)                                  0.853000
# 봄날의 소나기 Paper Umbrella                              0.532000
# 전야 前夜 The Eve                                       0.702000
# 피카부 Peek-A-Boo                                      0.902000
# 항상 (HANGSANG)                                       0.896000
#
# [3367 rows x 2 columns]

# %%
energy_h=merge5_df["Energy"]
position_h=merge5_df["Number of times in the chart TOP 50"]
correlation1 =stats.pearsonr(energy_h,position_h)
print(f"The correlation between both factors is {round(correlation1[0],2)}")
# Out:
# The correlation between both factors is 0.0

# %%
x_values_energyp=merge5_df["Energy"]
y_values_positionp=merge5_df["Number of times in the chart TOP 50"]
(slope,intercept,rvalue,pvalue,stderr) = stats.linregress(x_values_energyp,y_values_positionp)
regress_values = x_values_energyp* slope + intercept
line_eq= "y ="+str(round(slope,2))+"x + "+ str(round(intercept,2))
print(line_eq)
plt.scatter(x_values_energyp, y_values_positionp)
plt.plot(x_values_energyp,regress_values)

plt.annotate(line_eq,(1,2),fontsize=15,color="green")
plt.xlabel("Energy")
plt.ylabel("Number of times in the chart TOP 50")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# y =0.04x + 13.29
# The r-squared is: 1.0151555145214378e-07

# %%
#SAMPLE

# %%
subset=merge5_df.sample(90)
subset
# Out:
#                                                    Number of times in the chart TOP 50  \
# Track Name
# Connection                                                                           7
# Rain on Me                                                                           6
# Te Odio y Te Quiero                                                                  7
# El corrido de Miguel Rivera - Inspirado en "Coco"                                   17
# Los locos adams                                                                     11
# ...                                                                                ...
# Para ser sincero                                                                     2
# Hands                                                                                3
# SAD!                                                                                31
# I Say a Little Prayer                                                                8
# Booty                                                                               41
#
#                                                      Energy
# Track Name
# Connection                                         0.602000
# Rain on Me                                         0.687000
# Te Odio y Te Quiero                                0.970000
# El corrido de Miguel Rivera - Inspirado en "Coco"  0.594765
# Los locos adams                                    0.473000
# ...                                                     ...
# Para ser sincero                                   0.617000
# Hands                                              0.638000
# SAD!                                               0.613000
# I Say a Little Prayer                              0.355000
# Booty                                              0.771000
#
# [90 rows x 2 columns]

# %%
energy_s=subset["Energy"]
position_s=subset["Number of times in the chart TOP 50"]
correlation2 =stats.pearsonr(energy_s,position_s)
print(f"The correlation between both factors is {round(correlation2[0],2)}")
# Out:
# The correlation between both factors is -0.09

# %%
x_values_energys=subset["Energy"]
x_values_positions=subset["Number of times in the chart TOP 50"]
(slope,intercept,rvalue,pvalue,stderr) = stats.linregress(x_values_energys,x_values_positions)
regress_values = x_values_energys* slope + intercept
line_eq= "y ="+str(round(slope,2))+"x + "+ str(round(intercept,2))
print(line_eq)
plt.scatter(x_values_energys, x_values_positions)
plt.plot(x_values_energys,regress_values)

plt.annotate(line_eq,(1,2),fontsize=15,color="green")
plt.xlabel("Energy")
plt.ylabel("Number of times in the chart TOP 50")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# y =-5.69x + 14.6
# The r-squared is: 0.008324322900030198

# %%
energy_boxplot=merge5_df["Energy"]

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Energy of the 50 Top songs')
ax1.set_ylabel('Energy')
ax1.boxplot(energy_boxplot)
plt.show()

# %%
quartiles_energy=energy_boxplot.quantile([.25,.5,.75])
lowerq_energy=quartiles_energy[0.25]
upperq_energy=quartiles_energy[0.75]
iqr_energy=upperq_energy-lowerq_energy

print(f"The lower quartile of energy is: {lowerq_energy}")
print(f"The upper quartile of energy is: {upperq_energy}")
print(f"The upper interquartile range of energy is: {iqr_energy}")
print(f"The median of energy is: {quartiles_energy[0.5]}")

lower_bound_energy=lowerq_energy - (1.5*iqr_energy)
upper_bound_energy=upperq_energy + (1.5*iqr_energy)
print(f"Values below {lower_bound_energy} could be the outliers.")
print(f"Values above {upper_bound_energy} could be the outliers.")
# Out:
# The lower quartile of energy is: 0.5295000000000001
# The upper quartile of energy is: 0.7940000000000003
# The upper interquartile range of energy is: 0.2645000000000002
# The median of energy is: 0.6813333333333333
# Values below 0.1327499999999998 could be the outliers.
# Values above 1.1907500000000004 could be the outliers.

# %%
energy_wo=merge5_df[(merge5_df >= lower_bound_energy).all(1)]
energy_wo
# Out:
#                                                     Number of times in the chart TOP 50  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...                                    6
# #Maldeamores                                                                         10
# #Natural                                                                             31
# (I Just) Died In Your Arms                                                            1
# (No One Knows Me) Like the Piano                                                      5
# ...                                                                                 ...
# 달라달라 (DALLA DALLA)                                                                   10
# 봄날의 소나기 Paper Umbrella                                                                3
# 전야 前夜 The Eve                                                                         1
# 피카부 Peek-A-Boo                                                                        6
# 항상 (HANGSANG)                                                                         7
#
#                                                       Energy
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...  0.719000
# #Maldeamores                                        0.804000
# #Natural                                            0.824677
# (I Just) Died In Your Arms                          0.726000
# (No One Knows Me) Like the Piano                    0.198000
# ...                                                      ...
# 달라달라 (DALLA DALLA)                                  0.853000
# 봄날의 소나기 Paper Umbrella                              0.532000
# 전야 前夜 The Eve                                       0.702000
# 피카부 Peek-A-Boo                                      0.902000
# 항상 (HANGSANG)                                       0.896000
#
# [3330 rows x 2 columns]

# %%
energy_wo2=energy_wo["Energy"]
fig1, ax1 = plt.subplots()
ax1.set_title('Energy of the 50 Top songs')
ax1.set_ylabel('Energy')
ax1.boxplot(energy_wo2)
plt.show()

# %%
energy_without_outliers=energy_wo["Energy"]
position_without_outliers=energy_wo["Number of times in the chart TOP 50"]
correlation3 =stats.pearsonr(energy_without_outliers,position_without_outliers)
print(f"The correlation between both factors is {round(correlation3[0],2)}")
# Out:
# The correlation between both factors is -0.01

# %% [markdown]
# ## If a song has a higher level of danceability, then it will be more likely to be in the Top 50 throughout the next year.

# %%
dance_data=pd.DataFrame(track_name["danceability"].mean())
dance_data.rename(columns={"danceability":"Danceability"},inplace=True)
dance_data.head()
# Out:
#                                                     Danceability
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...      0.754000
# #Maldeamores                                            0.728000
# #Natural                                                0.804613
# (I Just) Died In Your Arms                              0.625000
# (No One Knows Me) Like the Piano                        0.619000

# %%
merge_df=pd.merge(track_name_count, dance_data, on="Track Name", how="outer")
merge_df
# Out:
#                                                     Number of times in the chart TOP 50  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...                                    6
# #Maldeamores                                                                         10
# #Natural                                                                             31
# (I Just) Died In Your Arms                                                            1
# (No One Knows Me) Like the Piano                                                      5
# ...                                                                                 ...
# 달라달라 (DALLA DALLA)                                                                   10
# 봄날의 소나기 Paper Umbrella                                                                3
# 전야 前夜 The Eve                                                                         1
# 피카부 Peek-A-Boo                                                                        6
# 항상 (HANGSANG)                                                                         7
#
#                                                     Danceability
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...      0.754000
# #Maldeamores                                            0.728000
# #Natural                                                0.804613
# (I Just) Died In Your Arms                              0.625000
# (No One Knows Me) Like the Piano                        0.619000
# ...                                                          ...
# 달라달라 (DALLA DALLA)                                      0.790000
# 봄날의 소나기 Paper Umbrella                                  0.471000
# 전야 前夜 The Eve                                           0.636000
# 피카부 Peek-A-Boo                                          0.839000
# 항상 (HANGSANG)                                           0.832000
#
# [3367 rows x 2 columns]

# %%
dance_p=merge_df["Danceability"]
position_p=merge_df["Number of times in the chart TOP 50"]
correlation4 =stats.pearsonr(dance_p,position_p)
print(f"The correlation between both factors is {round(correlation4[0],2)}")
# Out:
# The correlation between both factors is 0.15

# %%
x_values_dancep=merge_df["Danceability"]
y_values_dposition=merge_df["Number of times in the chart TOP 50"]
(slope,intercept,rvalue,pvalue,stderr) = stats.linregress(x_values_dancep,y_values_dposition)
regress_values2 = x_values_dancep* slope + intercept
line_eq= "y ="+str(round(slope,2))+"x + "+ str(round(intercept,2))
print(line_eq)
plt.scatter(x_values_dancep, y_values_dposition)
plt.plot(x_values_dancep,regress_values2)

plt.annotate(line_eq,(1,2),fontsize=15,color="green")
plt.xlabel("Danceability")
plt.ylabel("Number of times in the chart TOP 50")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# y =22.78x + -1.31
# The r-squared is: 0.022463035694865272

# %%
#SAMPLE

# %%
subset_d=merge_df.sample(90)
subset_d
# Out:
#                                                     Number of times in the chart TOP 50  \
# Track Name
# Vitamina                                                                              5
# Alerta Sísmica                                                                        6
# La Diabla                                                                             2
# El Ultimo Beso                                                                        4
# Cruel World                                                                           3
# ...                                                                                 ...
# Love Incredible (feat. Camila Cabello)                                                6
# What's the Use?                                                                       5
# The Apprentice (feat. Rag'n'Bone Man, Zebra Kat...                                    1
# Stranger Things                                                                      12
# Oye Mujer                                                                            14
#
#                                                     Danceability
# Track Name
# Vitamina                                                   0.673
# Alerta Sísmica                                             0.802
# La Diabla                                                  0.745
# El Ultimo Beso                                             0.619
# Cruel World                                                0.480
# ...                                                          ...
# Love Incredible (feat. Camila Cabello)                     0.354
# What's the Use?                                            0.759
# The Apprentice (feat. Rag'n'Bone Man, Zebra Kat...         0.446
# Stranger Things                                            0.352
# Oye Mujer                                                  0.826
#
# [90 rows x 2 columns]

# %%
dance_s=subset_d["Danceability"]
position_s=subset_d["Number of times in the chart TOP 50"]
correlation5 =stats.pearsonr(position_s,dance_s)
print(f"The correlation between both factors is {round(correlation5[0],2)}")
# Out:
# The correlation between both factors is 0.26

# %%
x_values=subset_d["Danceability"]
y_values=subset_d["Number of times in the chart TOP 50"]
(slope,intercept,rvalue,pvalue,stderr) = stats.linregress(x_values,y_values)
regress_values = x_values* slope + intercept
line_eq= "y ="+str(round(slope,2))+"x + "+ str(round(intercept,2))
print(line_eq)
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values)

plt.annotate(line_eq,(1,2),fontsize=15,color="green")
plt.xlabel("Danceability")
plt.ylabel("Number of times in the chart TOP 50")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# y =35.14x + -10.25
# The r-squared is: 0.068644796680203

# %%
dance_boxplot=merge_df["Danceability"]
fig1, ax1 = plt.subplots()
ax1.set_title('Danceability of the 50 Top songs')
ax1.set_ylabel('Danceability')
ax1.boxplot(dance_boxplot)
plt.show()

# %%
quartiles_dance=dance_boxplot.quantile([.25,.5,.75])
lowerq_dance=quartiles_dance[0.25]
upperq_dance=quartiles_dance[0.75]
iqr_dance=upperq_dance-lowerq_dance

print(f"The lower quartile of danceability is: {lowerq_dance}")
print(f"The upper quartile of danceability is: {upperq_dance}")
print(f"The upper interquartile range of danceability is: {iqr_dance}")
print(f"The median of danceability is: {quartiles_dance[0.5]}")

lower_bound_dance=lowerq_dance - (1.5*iqr)
upper_bound_dance=upperq + (1.5*iqr)
print(f"Values below {lower_bound_dance} could be the outliers.")
print(f"Values above {upper_bound_dance} could be the outliers.")
# Out:
# The lower quartile of danceability is: 0.545
# The upper quartile of danceability is: 0.757
# The upper interquartile range of danceability is: 0.21199999999999997
# The median of danceability is: 0.661
# Values below 0.2270000000000001 could be the outliers.
# Values above 1.075 could be the outliers.

# %%
dance_wo=merge_df[(merge_df >= 0.2270000000000001).all(1)]
dance_wo
# Out:
#                                                     Number of times in the chart TOP 50  \
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...                                    6
# #Maldeamores                                                                         10
# #Natural                                                                             31
# (I Just) Died In Your Arms                                                            1
# (No One Knows Me) Like the Piano                                                      5
# ...                                                                                 ...
# 달라달라 (DALLA DALLA)                                                                   10
# 봄날의 소나기 Paper Umbrella                                                                3
# 전야 前夜 The Eve                                                                         1
# 피카부 Peek-A-Boo                                                                        6
# 항상 (HANGSANG)                                                                         7
#
#                                                     Danceability
# Track Name
# "Was He Slow?" - Music From The Motion Picture ...      0.754000
# #Maldeamores                                            0.728000
# #Natural                                                0.804613
# (I Just) Died In Your Arms                              0.625000
# (No One Knows Me) Like the Piano                        0.619000
# ...                                                          ...
# 달라달라 (DALLA DALLA)                                      0.790000
# 봄날의 소나기 Paper Umbrella                                  0.471000
# 전야 前夜 The Eve                                           0.636000
# 피카부 Peek-A-Boo                                          0.839000
# 항상 (HANGSANG)                                           0.832000
#
# [3343 rows x 2 columns]

# %%
dance_without_outliers=dance_wo["Danceability"]
position2_without_outliers=dance_wo["Number of times in the chart TOP 50"]
correlation6 =stats.pearsonr(dance_without_outliers,position2_without_outliers)
print(f"The correlation between both factors is {round(correlation6[0],2)}")
# Out:
# The correlation between both factors is 0.15
